|
# |    time_elapsed     | 37       |
# |    total_timesteps  | 75765    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.244    |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 2005     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 76357    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 137      |
# |    exploration_rate | 0.239    |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 2007     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 76892    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.232    |
# ...
# |    learning_rate    | 0.0001   |
# |    loss             | 0.021    |
# |    n_updates        | 212841   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.99e+03 |
# |    ep_rew_mean      | 601      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3828     |
# |    fps              | 844      |
# |    time_elapsed     | 1127     |
# |    total_timesteps  | 952600   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.117    |
# |    n_updates        | 213149   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.98e+03 |
# |    ep_rew_mean      | 597      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3832     |
# |    fps              | 844      |
# |    time_elapsed     | 1129     |
# |    total_timesteps  | 954076   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0156   |
# |    n_updates        | 213518   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.98e+03 |
# |    ep_rew_mean      | 595      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3836     |
# |    fps              | 845      |
# |    time_elapsed     | 1131     |
# |    total_timesteps  | 956089   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0123   |
# |    n_updates        | 214022   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.97e+03 |
# |    ep_rew_mean      | 595      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3840     |
# |    fps              | 845      |
# |    time_elapsed     | 1133     |
# |    total_timesteps  | 957907   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0236   |
# |    n_updates        | 214476   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.97e+03 |
# |    ep_rew_mean      | 594      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3844     |
# |    fps              | 845      |
# |    time_elapsed     | 1135     |
# |    total_timesteps  | 959664   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0177   |
# |    n_updates        | 214915   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.95e+03 |
# |    ep_rew_mean      | 593      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3848     |
# |    fps              | 845      |
# |    time_elapsed     | 1137     |
# |    total_timesteps  | 961203   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0182   |
# |    n_updates        | 215300   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.95e+03 |
# |    ep_rew_mean      | 596      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3852     |
# |    fps              | 845      |
# |    time_elapsed     | 1140     |
# |    total_timesteps  | 963798   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0217   |
# |    n_updates        | 215949   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.94e+03 |
# |    ep_rew_mean      | 594      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3856     |
# |    fps              | 845      |
# |    time_elapsed     | 1142     |
# |    total_timesteps  | 965797   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.018    |
# |    n_updates        | 216449   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.94e+03 |
# |    ep_rew_mean      | 594      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3860     |
# |    fps              | 845      |
# |    time_elapsed     | 1143     |
# |    total_timesteps  | 966994   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.042    |
# |    n_updates        | 216748   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.93e+03 |
# |    ep_rew_mean      | 592      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3864     |
# |    fps              | 845      |
# |    time_elapsed     | 1145     |
# |    total_timesteps  | 968587   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0358   |
# |    n_updates        | 217146   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.93e+03 |
# |    ep_rew_mean      | 591      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3868     |
# |    fps              | 845      |
# |    time_elapsed     | 1147     |
# |    total_timesteps  | 969980   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0204   |
# |    n_updates        | 217494   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.91e+03 |
# |    ep_rew_mean      | 588      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3872     |
# |    fps              | 845      |
# |    time_elapsed     | 1148     |
# |    total_timesteps  | 971249   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0202   |
# |    n_updates        | 217812   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.89e+03 |
# |    ep_rew_mean      | 586      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3876     |
# |    fps              | 845      |
# |    time_elapsed     | 1150     |
# |    total_timesteps  | 972889   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0132   |
# |    n_updates        | 218222   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.89e+03 |
# |    ep_rew_mean      | 586      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3880     |
# |    fps              | 845      |
# |    time_elapsed     | 1152     |
# |    total_timesteps  | 974614   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0353   |
# |    n_updates        | 218653   |
# ----------------------------------
# Eval num_timesteps=975000, episode_reward=567.00 +/- 35.58
# Episode length: 3700.80 +/- 397.54
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.7e+03  |
# |    mean_reward      | 567      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 975000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0238   |
# |    n_updates        | 218749   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.9e+03  |
# |    ep_rew_mean      | 587      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3884     |
# |    fps              | 843      |
# |    time_elapsed     | 1157     |
# |    total_timesteps  | 975724   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00818  |
# |    n_updates        | 218930   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.88e+03 |
# |    ep_rew_mean      | 585      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3888     |
# |    fps              | 843      |
# |    time_elapsed     | 1158     |
# |    total_timesteps  | 977194   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0272   |
# |    n_updates        | 219298   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.91e+03 |
# |    ep_rew_mean      | 590      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3892     |
# |    fps              | 843      |
# |    time_elapsed     | 1161     |
# |    total_timesteps  | 979670   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.013    |
# |    n_updates        | 219917   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.9e+03  |
# |    ep_rew_mean      | 595      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3896     |
# |    fps              | 843      |
# |    time_elapsed     | 1164     |
# |    total_timesteps  | 982332   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0332   |
# |    n_updates        | 220582   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.88e+03 |
# |    ep_rew_mean      | 596      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3900     |
# |    fps              | 843      |
# |    time_elapsed     | 1166     |
# |    total_timesteps  | 983651   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0166   |
# |    n_updates        | 220912   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.86e+03 |
# |    ep_rew_mean      | 592      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3904     |
# |    fps              | 843      |
# |    time_elapsed     | 1167     |
# |    total_timesteps  | 984813   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0347   |
# |    n_updates        | 221203   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.91e+03 |
# |    ep_rew_mean      | 597      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3908     |
# |    fps              | 843      |
# |    time_elapsed     | 1169     |
# |    total_timesteps  | 986968   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0272   |
# |    n_updates        | 221741   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.91e+03 |
# |    ep_rew_mean      | 595      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3912     |
# |    fps              | 843      |
# |    time_elapsed     | 1172     |
# |    total_timesteps  | 988932   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0338   |
# |    n_updates        | 222232   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.9e+03  |
# |    ep_rew_mean      | 596      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3916     |
# |    fps              | 843      |
# |    time_elapsed     | 1174     |
# |    total_timesteps  | 990868   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0912   |
# |    n_updates        | 222716   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.94e+03 |
# |    ep_rew_mean      | 599      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3920     |
# |    fps              | 843      |
# |    time_elapsed     | 1176     |
# |    total_timesteps  | 993234   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0252   |
# |    n_updates        | 223308   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.94e+03 |
# |    ep_rew_mean      | 599      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3924     |
# |    fps              | 843      |
# |    time_elapsed     | 1178     |
# |    total_timesteps  | 994593   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0104   |
# |    n_updates        | 223648   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.94e+03 |
# |    ep_rew_mean      | 597      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3928     |
# |    fps              | 843      |
# |    time_elapsed     | 1180     |
# |    total_timesteps  | 996405   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00898  |
# |    n_updates        | 224101   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.97e+03 |
# |    ep_rew_mean      | 605      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3932     |
# |    fps              | 844      |
# |    time_elapsed     | 1182     |
# |    total_timesteps  | 997727   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0136   |
# |    n_updates        | 224431   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.97e+03 |
# |    ep_rew_mean      | 605      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3936     |
# |    fps              | 844      |
# |    time_elapsed     | 1183     |
# |    total_timesteps  | 998917   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00855  |
# |    n_updates        | 224729   |
# ----------------------------------
# Eval num_timesteps=1000000, episode_reward=509.00 +/- 201.16
# Episode length: 3601.40 +/- 780.79
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.6e+03  |
# |    mean_reward      | 509      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 1000000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0144   |
# |    n_updates        | 224999   |
# ----------------------------------
# Saving to logs//dqn/SpaceInvadersNoFrameskip-v4_4

# %% [markdown]
# #### Solution

# %%
# !python -m rl_zoo3.train --algo dqn  --env SpaceInvadersNoFrameskip-v4 -f logs/ -c dqn.yml

# %% [markdown]
# ## Let's evaluate our agent 👀
# - RL-Baselines3-Zoo provides `enjoy.py`, a python script to evaluate our agent. In most RL libraries, we call the evaluation script `enjoy.py`.
# - Let's evaluate it for 5000 timesteps 🔥

# %%
# !python -m rl_zoo3.enjoy  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps 5000  --folder logs/
# Out:
# Loading latest experiment, id=4
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_4/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# Stacking 4 frames
# Atari Episode Score: 540.00
# Atari Episode Length 3803
# Atari Episode Score: 550.00
# Atari Episode Length 3573
# Atari Episode Score: 575.00
# Atari Episode Length 4567
# Atari Episode Score: 570.00
# Atari Episode Length 4224
# Atari Episode Score: 470.00
# Atari Episode Length 4001

# %% [markdown]
# #### Solution

# %%
# !python -m rl_zoo3.enjoy  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps 5000  --folder logs/

# %% [markdown]
# ## Publish our trained model on the Hub 🚀
# Now that we saw we got good results after the training, we can publish our trained model on the hub 🤗 with one line of code.
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit3/space-invaders-model.gif" alt="Space Invaders model">

# %% [markdown]
# By using `rl_zoo3.push_to_hub` **you evaluate, record a replay, generate a model card of your agent and push it to the hub**.
#
# This way:
# - You can **showcase our work** 🔥
# - You can **visualize your agent playing** 👀
# - You can **share with the community an agent that others can use** 💾
# - You can **access a leaderboard 🏆 to see how well your agent is performing compared to your classmates** 👉  https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard

# %% [markdown]
# To be able to share your model with the community there are three more steps to follow:
#
# 1️⃣ (If it's not already done) create an account to HF ➡ https://huggingface.co/join
#
# 2️⃣ Sign in and then, you need to store your authentication token from the Hugging Face website.
# - Create a new token (https://huggingface.co/settings/tokens) **with write role**
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/create-token.jpg" alt="Create HF Token">

# %% [markdown]
# - Copy the token
# - Run the cell below and past the token

# %%
from huggingface_hub import notebook_login # To log to our Hugging Face account to be able to upload models to the Hub.
notebook_login()
# !git config --global credential.helper store
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# If you don't want to use a Google Colab or a Jupyter Notebook, you need to use this command instead: `huggingface-cli login`

# %% [markdown]
# 3️⃣ We're now ready to push our trained agent to the 🤗 Hub 🔥

# %% [markdown]
# Let's run push_to_hub.py file to upload our trained agent to the Hub.
#
# `--repo-name `: The name of the repo
#
# `-orga`: Your Hugging Face username
#
# `-f`: Where the trained model folder is (in our case `logs`)
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit3/select-id.png" alt="Select Id">

# %%
# !python -m rl_zoo3.push_to_hub  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --repo-name dqn-SpaceInvadersNoFrameskip-v4 -orga carpit680 -f logs/
# Out:
# Loading latest experiment, id=4
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_4/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Uploading to carpit680/dqn-SpaceInvadersNoFrameskip-v4, make sure to have the rights
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to some
# minutes if video generation is activated. This is a work in progress: if you
# encounter a bug, please open an issue.
# /home/rightbot/miniconda3/envs/drl/lib/python3.11/site-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'Repository' (from 'huggingface_hub.repository') is deprecated and will be removed from version '1.0'. Please prefer the http-based alternatives instead. Given its large adoption in legacy code, the complete removal is only planned on next major release.
# For more details, please read https://huggingface.co/docs/huggingface_hub/concepts/git_vs_http.
#   warnings.warn(warning_message, FutureWarning)
# /home/rightbot/Documents/arpit/hf-deep-rl/hub/dqn-SpaceInvadersNoFrameskip-v4 is already a clone of https://huggingface.co/carpit680/dqn-SpaceInvadersNoFrameskip-v4. Make sure you pull the latest changes with `repo.git_pull()`.
# WARNING:huggingface_hub.repository:/home/rightbot/Documents/arpit/hf-deep-rl/hub/dqn-SpaceInvadersNoFrameskip-v4 is already a clone of https://huggingface.co/carpit680/dqn-SpaceInvadersNoFrameskip-v4. Make sure you pull the latest changes with `repo.git_pull()`.
# Traceback (most recent call last):
#   File "/home/rightbot/miniconda3/envs/drl/lib/python3.11/site-packages/huggingface_hub/repository.py", line 1002, in git_pull
#     result = run_subprocess(command, self.local_dir)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/rightbot/miniconda3/envs/drl/lib/python3.11/site-packages/huggingface_hub/utils/_subprocess.py", line 83, in run_subprocess
#     return subprocess.run(
#            ^^^^^^^^^^^^^^^
#   File "/home/rightbot/miniconda3/envs/drl/lib/python3.11/subprocess.py", line 571, in run
#     raise CalledProcessError(retcode, process.args,
# subprocess.CalledProcessError: Command '['git', 'pull', '--rebase']' returned non-zero exit status 128.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/rightbot/miniconda3/envs/drl/lib/python3.11/site-packages/rl_zoo3/push_to_hub.py", line 410, in <module>
#     package_to_hub(
#   File "/home/rightbot/miniconda3/envs/drl/lib/python3.11/site-packages/rl_zoo3/push_to_hub.py", line 202, in package_to_hub
#     repo.git_pull(rebase=True)
#   File "/home/rightbot/miniconda3/envs/drl/lib/python3.11/site-packages/huggingface_hub/repository.py", line 1005, in git_pull
#     raise EnvironmentError(exc.stderr)
# OSError: error: cannot pull with rebase: You have unstaged changes.
# error: please commit or stash them.

# %% [markdown]
# #### Solution

# %%
# !python -m rl_zoo3.push_to_hub  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --repo-name dqn-SpaceInvadersNoFrameskip-v4  -orga ThomasSimonini  -f logs/

# %% [markdown]
# ###.

# %% [markdown]
# Congrats 🥳 you've just trained and uploaded your first Deep Q-Learning agent using RL-Baselines-3 Zoo. The script above should have displayed a link to a model repository such as https://huggingface.co/ThomasSimonini/dqn-SpaceInvadersNoFrameskip-v4. When you go to this link, you can:
#
# - See a **video preview of your agent** at the right.
# - Click "Files and versions" to see all the files in the repository.
# - Click "Use in stable-baselines3" to get a code snippet that shows how to load the model.
# - A model card (`README.md` file) which gives a description of the model and the hyperparameters you used.
#
# Under the hood, the Hub uses git-based repositories (don't worry if you don't know what git is), which means you can update the model with new versions as you experiment and improve your agent.
#
# **Compare the results of your agents with your classmates** using the [leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) 🏆

# %% [markdown]
# ## Load a powerful trained model 🔥
# - The Stable-Baselines3 team uploaded **more than 150 trained Deep Reinforcement Learning agents on the Hub**.
#
# You can find them here: 👉 https://huggingface.co/sb3
#
# Some examples:
# - Asteroids: https://huggingface.co/sb3/dqn-AsteroidsNoFrameskip-v4
# - Beam Rider: https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4
# - Breakout: https://huggingface.co/sb3/dqn-BreakoutNoFrameskip-v4
# - Road Runner: https://huggingface.co/sb3/dqn-RoadRunnerNoFrameskip-v4
#
# Let's load an agent playing Beam Rider: https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>

# %% [markdown]
# 1. We download the model using `rl_zoo3.load_from_hub`, and place it in a new folder that we can call `rl_trained`

# %%
# Download model and save it into the logs/ folder
# !python -m rl_zoo3.load_from_hub --algo dqn --env BeamRiderNoFrameskip-v4 -orga sb3 -f rl_trained/

# %% [markdown]
# 2. Let's evaluate if for 5000 timesteps

# %%
# !python -m rl_zoo3.enjoy --algo dqn --env BeamRiderNoFrameskip-v4 -n 5000  -f rl_trained/ --no-render

# %% [markdown]
# Why not trying to train your own **Deep Q-Learning Agent playing BeamRiderNoFrameskip-v4? 🏆.**
#
# If you want to try, check https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4#hyperparameters **in the model card, you have the hyperparameters of the trained agent.**

# %% [markdown]
# But finding hyperparameters can be a daunting task. Fortunately, we'll see in the next Unit, how we can **use Optuna for optimizing the Hyperparameters 🔥.**

# %% [markdown]
# ## Some additional challenges 🏆
# The best way to learn **is to try things by your own**!
#
# In the [Leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) you will find your agents. Can you get to the top?
#
# Here's a list of environments you can try to train your agent with:
# - BeamRiderNoFrameskip-v4
# - BreakoutNoFrameskip-v4
# - EnduroNoFrameskip-v4
# - PongNoFrameskip-v4
#
# Also, **if you want to learn to implement Deep Q-Learning by yourself**, you definitely should look at CleanRL implementation: https://github.com/vwxyzjn/cleanrl/blob/master/cleanrl/dqn_atari.py
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit4/atari-envs.gif" alt="Environments"/>

# %% [markdown]
# ________________________________________________________________________
# Congrats on finishing this chapter!
#
# If you’re still feel confused with all these elements...it's totally normal! **This was the same for me and for all people who studied RL.**
#
# Take time to really **grasp the material before continuing and try the additional challenges**. It’s important to master these elements and having a solid foundations.
#
# In the next unit, **we’re going to learn about [Optuna](https://optuna.org/)**. One of the most critical task in Deep Reinforcement Learning is to find a good set of training hyperparameters. And Optuna is a library that helps you to automate the search.

# %% [markdown]
# ### This is a course built with you 👷🏿‍♀️
#
# Finally, we want to improve and update the course iteratively with your feedback. If you have some, please fill this form 👉 https://forms.gle/3HgA7bEHwAmmLfwh9
#
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the Github Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# See you on Bonus unit 2! 🔥

# %% [markdown]
# ### Keep Learning, Stay Awesome 🤗
